# %%
# !pip install kraken
# !kraken --version

# %%
# !find -type f -name "*.xml" > output.txt

# %%
# !ketos compile -F output.txt -f alto

# %%
# !ketos train -o ukr_kobzar -r 0.001 -B 1 --lag 20  -f binary -d cuda:0 -s '[1,120,0,1 Cr3,13,32 Do0.1,2 Mp2,2 Cr3,13,32 Do0.1,2 Mp2,2 Cr3,9,64 Do0.1,2 Mp2,2 Cr3,9,64 Do0.1,2 S1(1x0)1,3 Lbx200 Do0.1,2 Lbx200 Do.1,2 Lbx200 Do]' --augment --workers 20 dataset.arrow

# %%
# !ls
